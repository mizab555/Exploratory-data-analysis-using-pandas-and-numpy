# %%
import pandas as pd
import re

# %%
hpns1=pd.read_csv('World_Happiness_2015.csv')

# %%
hpns2=pd.read_csv('World_Happiness_2016.csv')

# %%
hpns3=pd.read_csv('World_Happiness_2017 (1).csv')

# %%
y=pd.merge(pd.merge(hpns1,hpns2,on='Country'),hpns3,on='Country')
y
# Out:
#          Country                         Region_x  Happiness Rank_x  \
# 0    Switzerland                   Western Europe                 1
# 1        Iceland                   Western Europe                 2
# 2        Denmark                   Western Europe                 3
# 3         Norway                   Western Europe                 4
# 4         Canada                    North America                 5
# ..           ...                              ...               ...
# 141       Rwanda               Sub-Saharan Africa               154
# 142        Benin               Sub-Saharan Africa               155
# 143        Syria  Middle East and Northern Africa               156
# 144      Burundi               Sub-Saharan Africa               157
# 145         Togo               Sub-Saharan Africa               158
#
#      Happiness Score_x  Standard Error  Economy (GDP per Capita)_x  Family_x  \
# ...

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          146 non-null    object
#  1   Region_x                         146 non-null    object
#  2   Happiness Rank_x                 146 non-null    int64
#  3   Happiness Score_x                146 non-null    float64
#  4   Standard Error                   146 non-null    float64
#  5   Economy (GDP per Capita)_x       146 non-null    float64
#  6   Family_x                         146 non-null    float64
#  7   Health (Life Expectancy)_x       146 non-null    float64
#  8   Freedom_x                        146 non-null    float64
#  9   Trust (Government Corruption)_x  146 non-null    float64
#  10  Generosity_x                     146 non-null    float64
#  11  Dystopia Residual_x              146 non-null    float64
# ...

# %%
col=y.loc[:,['Region_y']]
x=re.findall('Western Europe',col)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-47d7e593e236> in <module>
#       1 col=y.loc[:,['Region_y']]
# ----> 2 x=re.findall('Western Europe',col)
#
# ~\anaconda3\lib\re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
col=y.loc[:,['Region_y']]
# Out:
#                             Region_y
# 0                     Western Europe
# 1                     Western Europe
# 2                     Western Europe
# 3                     Western Europe
# 4                      North America
# ..                               ...
# 141               Sub-Saharan Africa
# 142               Sub-Saharan Africa
# 143  Middle East and Northern Africa
# 144               Sub-Saharan Africa
# 145               Sub-Saharan Africa
#
# [146 rows x 1 columns]

# %% [raw]
# aaa=y.groupby('Region_x')
# bbb=aaa.get_group('Sub-Saharan Africa')
# bbb

# %%
bbb1=bbb.loc[:,'Country']
bbb1
# Out:
# 67               Mauritius
# 73                 Nigeria
# 80                  Zambia
# 103           South Africa
# 104                  Ghana
# 105               Zimbabwe
# 106                Liberia
# 108                  Sudan
# 110       Congo (Kinshasa)
# 112               Ethiopia
# 113           Sierra Leone
# 114             Mauritania
# 115                  Kenya
# 117               Botswana
# 120                 Malawi
# 122               Cameroon
# 126                 Angola
# 127                   Mali
# 128    Congo (Brazzaville)
# 129                 Uganda
# 130                Senegal
# 131                  Gabon
# 132                  Niger
# 134               Tanzania
# 135             Madagascar
# 136                   Chad
# 137                 Guinea
# 138            Ivory Coast
# 139           Burkina Faso
# 141                 Rwanda
# 142                  Benin
# 144                Burundi
# 145                   Togo
# Name: Country, dtype: object

# %%
column={'Region_x':'region'}
bbb1=y.rename(column,axis=1)
bbb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          146 non-null    object
#  1   region                           146 non-null    object
#  2   Happiness Rank_x                 146 non-null    int64
#  3   Happiness Score_x                146 non-null    float64
#  4   Standard Error                   146 non-null    float64
#  5   Economy (GDP per Capita)_x       146 non-null    float64
#  6   Family_x                         146 non-null    float64
#  7   Health (Life Expectancy)_x       146 non-null    float64
#  8   Freedom_x                        146 non-null    float64
#  9   Trust (Government Corruption)_x  146 non-null    float64
#  10  Generosity_x                     146 non-null    float64
#  11  Dystopia Residual_x              146 non-null    float64
# ...

# %%
pattern=r'([i][a])'
col2=y['Country'].str.extract(pattern)

# %%
y['col2']=col2
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 36 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          146 non-null    object
#  1   Region_x                         146 non-null    object
#  2   Happiness Rank_x                 146 non-null    int64
#  3   Happiness Score_x                146 non-null    float64
#  4   Standard Error                   146 non-null    float64
#  5   Economy (GDP per Capita)_x       146 non-null    float64
#  6   Family_x                         146 non-null    float64
#  7   Health (Life Expectancy)_x       146 non-null    float64
#  8   Freedom_x                        146 non-null    float64
#  9   Trust (Government Corruption)_x  146 non-null    float64
#  10  Generosity_x                     146 non-null    float64
#  11  Dystopia Residual_x              146 non-null    float64
# ...

# %%
y['Happiness Score_x'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# Name: Happiness Score_x, Length: 146, dtype: bool

# %%
y.isnull().sum()
# Out:
# Country                              0
# Region_x                             0
# Happiness Rank_x                     0
# Happiness Score_x                    0
# Standard Error                       0
# Economy (GDP per Capita)_x           0
# Family_x                             0
# Health (Life Expectancy)_x           0
# Freedom_x                            0
# Trust (Government Corruption)_x      0
# Generosity_x                         0
# Dystopia Residual_x                  0
# Region_y                             0
# Happiness Rank_y                     0
# Happiness Score_y                    0
# Lower Confidence Interval            0
# Upper Confidence Interval            0
# Economy (GDP per Capita)_y           0
# Family_y                             0
# Health (Life Expectancy)_y           0
# Freedom_y                            0
# Trust (Government Corruption)_y      0
# Generosity_y                         0
# Dystopia Residual_y                  0
# ...

# %%
y['Country'].str.upper()
# Out:
# 0      SWITZERLAND
# 1          ICELAND
# 2          DENMARK
# 3           NORWAY
# 4           CANADA
#           ...
# 141         RWANDA
# 142          BENIN
# 143          SYRIA
# 144        BURUNDI
# 145           TOGO
# Name: Country, Length: 146, dtype: object
