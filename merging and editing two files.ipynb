# %%
import pandas as pd
import re

# %%
wld=pd.read_csv('World_dev.csv')
wld.shape
# Out:
# (247, 31)

# %%
wld.head(10)
# Out:
#   CountryCode            ShortName            TableName  \
# 0         AFG          Afghanistan          Afghanistan
# 1         ALB              Albania              Albania
# 2         DZA              Algeria              Algeria
# 3         ASM       American Samoa       American Samoa
# 4         ADO              Andorra              Andorra
# 5         AGO               Angola               Angola
# 6         ATG  Antigua and Barbuda  Antigua and Barbuda
# 7         ARB           Arab World           Arab World
# 8         ARG            Argentina            Argentina
# 9         ARM              Armenia              Armenia
#
#                                   LongName Alpha2Code           CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF         Afghan afghani
# 1                      Republic of Albania         AL           Albanian lek
# 2  People's Democratic Republic of Algeria         DZ         Algerian dinar
# ...

# %%
hpns=pd.read_csv('World_Happiness_2015.csv')
hpns.shape
# Out:
# (158, 12)

# %%
y=pd.merge(left=hpns,right=wld,how='left',left_on='Country',right_on='ShortName')
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 0 to 157
# Data columns (total 43 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country                                     158 non-null    object
#  1   Region_x                                    158 non-null    object
#  2   Happiness Rank                              158 non-null    int64
#  3   Happiness Score                             158 non-null    float64
#  4   Standard Error                              158 non-null    float64
#  5   Economy (GDP per Capita)                    158 non-null    float64
#  6   Family                                      158 non-null    float64
#  7   Health (Life Expectancy)                    158 non-null    float64
#  8   Freedom                                     158 non-null    float64
# ...

# %%
col={'SourceOfMostRecentIncomeAndExpenditureData':'iesurvey'}
y=y.rename(col,axis=1)
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 0 to 157
# Data columns (total 43 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region_x                       158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
y['CurrencyUnit'].head(20)
# Out:
# 0            Swiss franc
# 1          Iceland krona
# 2           Danish krone
# 3        Norwegian krone
# 4        Canadian dollar
# 5                   Euro
# 6                   Euro
# 7          Swedish krona
# 8     New Zealand dollar
# 9      Australian dollar
# 10    Israeli new shekel
# 11     Costa Rican colon
# 12                  Euro
# 13          Mexican peso
# 14           U.S. dollar
# 15        Brazilian real
# 16                  Euro
# 17                  Euro
# 18                  Euro
# 19         U.A.E. dirham
# Name: CurrencyUnit, dtype: object

# %%
def cur(i):
    return str(i).split()[-1]

# %%
y['currency']=y['CurrencyUnit'].apply(cur)
y['currency'].head()
# Out:
# 0     franc
# 1     krona
# 2     krone
# 3     krone
# 4    dollar
# Name: currency, dtype: object

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 158 entries, 0 to 157
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region_x                       158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
y['CurrencyUnit'][0].split()[-1]
# Out:
# 'franc'

# %%
y['CurrencyUnit'].str[-4:-1]
# Out:
# 0      ran
# 1      ron
# 2      ron
# 3      ron
# 4      lla
#       ...
# 153    ran
# 154    ran
# 155    NaN
# 156    ran
# 157    ran
# Name: CurrencyUnit, Length: 158, dtype: object

# %%
y['Happiness Score'].isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2d44ab95ba56> in <module>
# ----> 1 y['Happiness Score'].isnull()
#
# NameError: name 'y' is not defined
